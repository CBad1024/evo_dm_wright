# %% [markdown]
# Project file using Wright Fischer model. All the necessary imports are done below.

# %%
# !git clone https://github.com/CBad1024/evo_dm_wright.git

import os
os.chdir('evo_dm_wright')

# !pip install -e .

from evodm.dpsolve import dp_env, backwards_induction, value_iteration, policy_iteration
from evodm.evol_game import define_mira_landscapes, evol_env
from evodm.learner import DrugSelector, hyperparameters, practice
import numpy as np
import pandas as pd
from mira_mdp import main
# Out:
# Cloning into 'evo_dm_wright'...
# remote: Enumerating objects: 2095, done.
# remote: Counting objects: 100% (395/395), done.
# remote: Compressing objects: 100% (228/228), done.
# remote: Total 2095 (delta 231), reused 268 (delta 123), pack-reused 1700 (from 1)
# Receiving objects: 100% (2095/2095), 2.85 MiB | 19.58 MiB/s, done.
# Resolving deltas: 100% (1332/1332), done.
# Obtaining file:///Users/chaaranathb/Developer/GitRepo/evo_dm_wright/evo_dm_wright
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow~=2.18.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from evodm==1.1.2) (2.18.1)
# Requirement already satisfied: numpy in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from evodm==1.1.2) (2.0.2)
# Requirement already satisfied: scipy in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from evodm==1.1.2) (1.16.0)
# Requirement already satisfied: networkx in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from evodm==1.1.2) (3.5)
# Requirement already satisfied: pytest in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from evodm==1.1.2) (8.4.1)
# Requirement already satisfied: tqdm in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from evodm==1.1.2) (4.67.1)
# Requirement already satisfied: pymdptoolbox in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from evodm==1.1.2) (4.0b3)
# Requirement already satisfied: pandas in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from evodm==1.1.2) (2.3.0)
# Requirement already satisfied: matplotlib in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from evodm==1.1.2) (3.10.3)
# Requirement already satisfied: ruptures in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from evodm==1.1.2) (1.1.9)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (3.4.0)
# Requirement already satisfied: packaging in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (2.32.4)
# Requirement already satisfied: setuptools in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (75.8.2)
# Requirement already satisfied: six>=1.12.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorflow~=2.18.0->evodm==1.1.2) (0.37.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from matplotlib->evodm==1.1.2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from matplotlib->evodm==1.1.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from matplotlib->evodm==1.1.2) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from matplotlib->evodm==1.1.2) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from matplotlib->evodm==1.1.2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from matplotlib->evodm==1.1.2) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from matplotlib->evodm==1.1.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from pandas->evodm==1.1.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from pandas->evodm==1.1.2) (2025.2)
# Requirement already satisfied: iniconfig>=1 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from pytest->evodm==1.1.2) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from pytest->evodm==1.1.2) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from pytest->evodm==1.1.2) (2.19.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow~=2.18.0->evodm==1.1.2) (0.45.1)
# Requirement already satisfied: rich in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow~=2.18.0->evodm==1.1.2) (14.0.0)
# Requirement already satisfied: namex in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow~=2.18.0->evodm==1.1.2) (0.1.0)
# Requirement already satisfied: optree in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow~=2.18.0->evodm==1.1.2) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow~=2.18.0->evodm==1.1.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow~=2.18.0->evodm==1.1.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow~=2.18.0->evodm==1.1.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow~=2.18.0->evodm==1.1.2) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow~=2.18.0->evodm==1.1.2) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow~=2.18.0->evodm==1.1.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow~=2.18.0->evodm==1.1.2) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow~=2.18.0->evodm==1.1.2) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow~=2.18.0->evodm==1.1.2) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow~=2.18.0->evodm==1.1.2) (0.1.2)
# Installing collected packages: evodm
#   Attempting uninstall: evodm
#     Found existing installation: evodm 1.1.2
#     Not uninstalling evodm at /Users/chaaranathb/Developer/GitRepo/evo_dm_wright, outside environment /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv
#     Can't uninstall 'evodm'. No files were found to uninstall.
#   DEPRECATION: Legacy editable install of evodm==1.1.2 from file:///Users/chaaranathb/Developer/GitRepo/evo_dm_wright/evo_dm_wright (setup.py develop) is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457
#   Running setup.py develop for evodm
# Successfully installed evodm-1.1.2
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Main Code here

# %% [markdown]
# Now call the main code for execution

# %%
main()
# Out:
# Initializing MIRA environments (DP and Simulation)...
# /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/scipy/sparse/_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])
# /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Solving MDP with Backwards Induction (Finite Horizon)...
# Policy shape from Backwards Induction: (16, 16)
#
# Solving MDP with Value Iteration...
# /Users/chaaranathb/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/mdptoolbox/util.py:167: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using >= is inefficient. Try using < instead.
#   if (matrix >= 0).all():
# Policy shape from Value Iteration: (3, 3, 10, 10, 3, 3, 10, 0, 3, 3, 0, 2, 11, 3, 3, 13)
#
# Solving MDP with Policy Iteration...
# Policy shape from Policy Iteration: (3, 3, 10, 10, 3, 3, 10, 0, 3, 3, 0, 2, 11, 3, 3, 13)
#
# Using non-naive RL to solve system:
#   3%|2         | 14/500 [00:14<08:16,  1.02s/episodes]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 main()
#
# File ~/Developer/GitRepo/evo_dm_wright/mira_mdp.py:100, in main()
#      98 # --- RL Agent Training  ---
#      99 print("\nUsing non-naive RL to solve system:")
# --> 100 rewards_NN, agent_NN, _, __ = practice(learner_env, naive=False, prev_action=True, compute_implied_policy_bool=True)
#     101 policy_NN_one_hot = agent_NN.compute_implied_policy(update = True)
#     102 policy_NN = [np.argmax(a) for a in policy_NN_one_hot]
#
# File ~/Developer/GitRepo/evo_dm_wright/evodm/learner.py:524, in practice(agent, naive, standard_practice, dp_solution, pre_trained, discount_rate, policy, prev_action, wf, train_freq, compute_implied_policy_bool)
#     521             agent.env.update_drug(np.argmax(agent.get_qs()))
#     522         else:
#     523             agent.env.action = np.argmax(
# --> 524                 agent.get_qs())  # plus one because of the stupid fucking indexing system
#     525 else:
#     526     # Get random action
#     527     if standard_practice and not wf:
#     528         # Only change the action if fitness is above 0.9
#
# File ~/Developer/GitRepo/evo_dm_wright/evodm/learner.py:387, in DrugSelector.get_qs(self)
#     384 else:
#     385     return "error in get_qs()"
# --> 387 return self.model.predict(tens, verbose=0)[0]
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:505, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     500 @traceback_utils.filter_traceback
#     501 def predict(
#     502     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     503 ):
#     504     # Create an iterator that yields batches of input data.
# --> 505     epoch_iterator = TFEpochIterator(
#     506         x=x,
#     507         batch_size=batch_size,
#     508         steps_per_epoch=steps,
#     509         shuffle=False,
#     510         distribute_strategy=self.distribute_strategy,
#     511         steps_per_execution=self.steps_per_execution,
#     512     )
#     514     # Container that configures and calls callbacks.
#     515     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:726, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     724 super().__init__(*args, **kwargs)
#     725 self._distribute_strategy = distribute_strategy
# --> 726 dataset = self.data_adapter.get_tf_dataset()
#     727 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     728     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     729         dataset
#     730     )
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:231, in ArrayDataAdapter.get_tf_dataset(self)
#     228     dataset = dataset.with_options(options)
#     229     return dataset
# --> 231 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     232 if shuffle == "batch":
#     233     indices_dataset = indices_dataset.map(tf.random.shuffle)
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/data/ops/dataset_ops.py:2389, in DatasetV2.flat_map(self, map_func, name)
#    2385 # Loaded lazily due to a circular dependency (dataset_ops -> flat_map_op ->
#    2386 # dataset_ops).
#    2387 # pylint: disable=g-import-not-at-top,protected-access
#    2388 from tensorflow.python.data.ops import flat_map_op
# -> 2389 return flat_map_op._flat_map(self, map_func, name=name)
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/data/ops/flat_map_op.py:24, in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/data/ops/flat_map_op.py:33, in _FlatMapDataset.__init__(self, input_dataset, map_func, name)
#      30 def __init__(self, input_dataset, map_func, name=None):
#      32   self._input_dataset = input_dataset
# ---> 33   self._map_func = structured_function.StructuredFunctionWrapper(
#      34       map_func, self._transformation_name(), dataset=input_dataset)
#      35   if not isinstance(self._map_func.output_structure, dataset_ops.DatasetSpec):
#      36     raise TypeError(
#      37         "The `map_func` argument must return a `Dataset` object. Got "
#      38         f"{dataset_ops.get_type(self._map_func.output_structure)!r}.")
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/data/ops/structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1251, in Function.get_concrete_function(self, *args, **kwargs)
#    1249 def get_concrete_function(self, *args, **kwargs):
#    1250   # Implements PolymorphicFunction.get_concrete_function.
# -> 1251   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1252   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1253   return concrete
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1221, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1219   if self._variable_creation_config is None:
#    1220     initializers = []
# -> 1221     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1222     self._initialize_uninitialized_variables(initializers)
#    1224 if self._created_variables:
#    1225   # In this case we have created variables on the first call, so we run the
#    1226   # version which is guaranteed to never create variables.
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/framework/func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/data/ops/structured_function.py:231, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     230 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 231   ret = wrapper_helper(*args)
#     232   ret = structure.to_tensor_list(self._output_structure, ret)
#     233   return [ops.convert_to_tensor(t) for t in ret]
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/data/ops/structured_function.py:161, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     159 if not _should_unpack(nested_args):
#     160   nested_args = (nested_args,)
# --> 161 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     162 ret = variable_utils.convert_variables_to_tensors(ret)
#     163 if _should_pack(ret):
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:160, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_batch_indices(indices)
#     143 """Convert a Tensor of indices into a dataset of batched indices.
#     144
#     145 This step can be accomplished in several ways. The most natural is
#    (...)    157     A Dataset of batched indices.
#     158 """
#     159 num_in_full_batch = num_full_batches * batch_size
# --> 160 first_k_indices = tf.slice(indices, [0], [num_in_full_batch])
#     161 first_k_indices = tf.reshape(
#     162     first_k_indices, [num_full_batches, batch_size]
#     163 )
#     165 flat_dataset = tf.data.Dataset.from_tensor_slices(first_k_indices)
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/ops/array_ops.py:991, in slice(input_, begin, size, name)
#     939 @tf_export("slice")
#     940 @dispatch.add_dispatch_support
#     941 def slice(input_, begin, size, name=None):
#     942   # pylint: disable=redefined-builtin
#     943   """Extracts a slice from a tensor.
#     944
#     945   See also `tf.strided_slice`.
#    (...)    989     A `Tensor` the same type as `input_`.
#     990   """
# --> 991   return gen_array_ops._slice(input_, begin, size, name=name)
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/ops/gen_array_ops.py:9901, in _slice(input, begin, size, name)
#    9899     pass  # Add nodes to the TensorFlow graph.
#    9900 # Add nodes to the TensorFlow graph.
# -> 9901 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    9902       "Slice", input=input, begin=begin, size=size, name=name)
#    9903 _result = _outputs[:]
#    9904 if _execute.must_record_gradient():
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/framework/op_def_library.py:783, in _apply_op_helper(op_type_name, name, **keywords)
#     778 _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     779                        keywords, default_type_attr_map, attrs, inputs,
#     780                        input_types)
#     781 _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     782                        default_type_attr_map, attrs)
# --> 783 _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#     784 del attrs  # attrs is no longer authoritative, use attr_protos instead
#     785 _ExtractOutputStructure(op_type_name, op_def, attr_protos,
#     786                         output_structure)
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/framework/op_def_library.py:342, in _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#     340   _SatisfiesIntMinimumConstraint(attr_value.i, attr_def, key, op_type_name)
#     341 if attr_def.type == "type":
# --> 342   _SatisfiesTypeConstraint(attr_value.type, attr_def, key)
#     343 if attr_def.type == "list(type)":
#     344   for value in attr_value.list.type:
#
# File ~/Developer/GitRepo/evo_dm_wright/venv/lib/python3.11/site-packages/tensorflow/python/framework/op_def_library.py:55, in _SatisfiesTypeConstraint(dtype, attr_def, param_name)
#      53 if attr_def.HasField("allowed_values"):
#      54   allowed_list = attr_def.allowed_values.list.type
# ---> 55   allowed_values = ", ".join(dtypes.as_dtype(x).name for x in allowed_list)
#      56   if dtype not in allowed_list:
#      57     raise TypeError(
#      58         f"Value passed to parameter '{param_name}' has DataType "
#      59         f"{dtypes.as_dtype(dtype).name} not in list of allowed values: "
#      60         f"{allowed_values}")
#
# KeyboardInterrupt:
